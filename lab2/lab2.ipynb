# %%
import pandas as pd
import seaborn
from matplotlib import pyplot as plt
#import seaborn as sns
#from matplotlib import pyplot as plt

data = pd.read_excel("rolling_sales/rollingsales_bronx.xls", skiprows=4)
data
# Out:
#       BOROUGH               NEIGHBORHOOD  \
# 0           2  BATHGATE
# 1           2  BATHGATE
# 2           2  BATHGATE
# 3           2  BATHGATE
# 4           2  BATHGATE
# ...       ...                        ...
# 5263        2  WOODLAWN
# 5264        2  WOODLAWN
# 5265        2  WOODLAWN
# 5266        2  WOODLAWN
# 5267        2  WOODLAWN
#
#                            BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  \
# 0     01  ONE FAMILY HOMES                                            1
# 1     01  ONE FAMILY HOMES                                            1
# 2     01  ONE FAMILY HOMES                                            1
# 3     01  ONE FAMILY HOMES                                            1
# 4     02  TWO FAMILY HOMES                                            1
# ...                                            ...                  ...
# 5263  10  COOPS - ELEVATOR APARTMENTS                                 2
# 5264  10  COOPS - ELEVATOR APARTMENTS                                 2
# 5265  10  COOPS - ELEVATOR APARTMENTS                                 2
# 5266  10  COOPS - ELEVATOR APARTMENTS                                 2
# 5267  22  STORE BUILDINGS                                             4
#
#       BLOCK  LOT EASE-MENT BUILDING CLASS AT PRESENT  \
# 0      3028   25                                  A5
# 1      3039   28                                  A1
# 2      3046   39                                  A1
# 3      3046   52                                  A1
# 4      2900   61                                  S2
# ...     ...  ...       ...                       ...
# 5263   3398   87                                  D4
# 5264   3398   87                                  D4
# 5265   3398   97                                  D4
# 5266   3398   97                                  D4
# 5267   3387    3                                  K4
#
#                                         ADDRESS APART\nMENT\nNUMBER  ...  \
# 0     412 EAST 179TH STREET                                          ...
# 1     2329 WASHINGTON AVENUE                                         ...
# 2     2075 BATHGATE AVENUE                                           ...
# 3     2047 BATHGATE AVENUE                                           ...
# 4     406 EAST TREMONT AVENUE                                        ...
# ...                                         ...                 ...  ...
# 5263  4315 WEBSTER AVENUE, 4G                                        ...
# 5264  4315 WEBSTER AVENUE, 5D                                        ...
# 5265  4295 WEBSTER AVENUE, 2J                                        ...
# 5266  4295 WEBSTER AVENUE, 1G                                        ...
# 5267  4334 KATONAH AVENUE                                            ...
#
#       RESIDENTIAL UNITS  COMMERCIAL UNITS  TOTAL UNITS  LAND SQUARE FEET  \
# 0                     1                 0            1              1842
# 1                     1                 0            1              1103
# 2                     1                 0            1              1986
# 3                     1                 0            1              2329
# 4                     2                 1            3              1855
# ...                 ...               ...          ...               ...
# 5263                  0                 0            0                 0
# 5264                  0                 0            0                 0
# 5265                  0                 0            0                 0
# 5266                  0                 0            0                 0
# 5267                  6                 6           12             10000
#
#       GROSS SQUARE FEET  YEAR BUILT  TAX CLASS AT TIME OF SALE  \
# 0                  2048        1901                          1
# 1                  1290        1910                          1
# 2                  1344        1899                          1
# 3                  1431        1901                          1
# 4                  4452        1931                          1
# ...                 ...         ...                        ...
# 5263                  0        1958                          2
# 5264                  0        1958                          2
# 5265                  0        1957                          2
# 5266                  0        1957                          2
# 5267              11160        1991                          4
#
#      BUILDING CLASS AT TIME OF SALE SALE\nPRICE  SALE DATE
# 0                                A5      355000 2013-07-08
# 1                                A1      474819 2013-05-20
# 2                                A1      210000 2013-03-12
# 3                                A1      343116 2013-07-01
# 4                                S2           0 2012-08-31
# ...                             ...         ...        ...
# 5263                             D4      150000 2013-02-06
# 5264                             D4      108500 2013-04-10
# 5265                             D4      126000 2012-09-28
# 5266                             D4      125000 2013-05-23
# 5267                             K4           0 2012-12-17
#
# [5268 rows x 21 columns]

# %%
clean_data = pd.read_excel("rolling_sales/rollingsales_bronx.xls", skiprows=4)
clean_data.columns = [column.lower().replace("\n", "").replace(" ", "_").replace("-", "_") for column in clean_data.columns] 
clean_data
# Out:
#       borough               neighborhood  \
# 0           2  BATHGATE
# 1           2  BATHGATE
# 2           2  BATHGATE
# 3           2  BATHGATE
# 4           2  BATHGATE
# ...       ...                        ...
# 5263        2  WOODLAWN
# 5264        2  WOODLAWN
# 5265        2  WOODLAWN
# 5266        2  WOODLAWN
# 5267        2  WOODLAWN
#
#                            building_class_category tax_class_at_present  \
# 0     01  ONE FAMILY HOMES                                            1
# 1     01  ONE FAMILY HOMES                                            1
# 2     01  ONE FAMILY HOMES                                            1
# 3     01  ONE FAMILY HOMES                                            1
# 4     02  TWO FAMILY HOMES                                            1
# ...                                            ...                  ...
# 5263  10  COOPS - ELEVATOR APARTMENTS                                 2
# 5264  10  COOPS - ELEVATOR APARTMENTS                                 2
# 5265  10  COOPS - ELEVATOR APARTMENTS                                 2
# 5266  10  COOPS - ELEVATOR APARTMENTS                                 2
# 5267  22  STORE BUILDINGS                                             4
#
#       block  lot ease_ment building_class_at_present  \
# 0      3028   25                                  A5
# 1      3039   28                                  A1
# 2      3046   39                                  A1
# 3      3046   52                                  A1
# 4      2900   61                                  S2
# ...     ...  ...       ...                       ...
# 5263   3398   87                                  D4
# 5264   3398   87                                  D4
# 5265   3398   97                                  D4
# 5266   3398   97                                  D4
# 5267   3387    3                                  K4
#
#                                         address apartmentnumber  ...  \
# 0     412 EAST 179TH STREET                                      ...
# 1     2329 WASHINGTON AVENUE                                     ...
# 2     2075 BATHGATE AVENUE                                       ...
# 3     2047 BATHGATE AVENUE                                       ...
# 4     406 EAST TREMONT AVENUE                                    ...
# ...                                         ...             ...  ...
# 5263  4315 WEBSTER AVENUE, 4G                                    ...
# 5264  4315 WEBSTER AVENUE, 5D                                    ...
# 5265  4295 WEBSTER AVENUE, 2J                                    ...
# 5266  4295 WEBSTER AVENUE, 1G                                    ...
# 5267  4334 KATONAH AVENUE                                        ...
#
#       residential_units  commercial_units  total_units  land_square_feet  \
# 0                     1                 0            1              1842
# 1                     1                 0            1              1103
# 2                     1                 0            1              1986
# 3                     1                 0            1              2329
# 4                     2                 1            3              1855
# ...                 ...               ...          ...               ...
# 5263                  0                 0            0                 0
# 5264                  0                 0            0                 0
# 5265                  0                 0            0                 0
# 5266                  0                 0            0                 0
# 5267                  6                 6           12             10000
#
#       gross_square_feet  year_built  tax_class_at_time_of_sale  \
# 0                  2048        1901                          1
# 1                  1290        1910                          1
# 2                  1344        1899                          1
# 3                  1431        1901                          1
# 4                  4452        1931                          1
# ...                 ...         ...                        ...
# 5263                  0        1958                          2
# 5264                  0        1958                          2
# 5265                  0        1957                          2
# 5266                  0        1957                          2
# 5267              11160        1991                          4
#
#      building_class_at_time_of_sale saleprice  sale_date
# 0                                A5    355000 2013-07-08
# 1                                A1    474819 2013-05-20
# 2                                A1    210000 2013-03-12
# 3                                A1    343116 2013-07-01
# 4                                S2         0 2012-08-31
# ...                             ...       ...        ...
# 5263                             D4    150000 2013-02-06
# 5264                             D4    108500 2013-04-10
# 5265                             D4    126000 2012-09-28
# 5266                             D4    125000 2013-05-23
# 5267                             K4         0 2012-12-17
#
# [5268 rows x 21 columns]

# %%
building_categories = ["homes","condos", "apartments", "buildings", "residential", "factories", "garages", 
                       "warehouses", "land", "facilities"]

def add_build_category (category:str):
    buffer = ""
    for type in building_categories:
        if type.upper() in category:
            buffer = type
            break
    return buffer if buffer != "" else "other"
                                
                    
        
clean_data.insert(2,"type_building",[add_build_category(category) for category in clean_data.building_class_category.to_list()])
#sort_by_building_class = clean_data.groupby("building_class_category").count()
#sort_by_building_class
new_data_with_type_building = clean_data
new_data_with_type_building
# Out:
#       borough               neighborhood type_building  \
# 0           2  BATHGATE                          homes
# 1           2  BATHGATE                          homes
# 2           2  BATHGATE                          homes
# 3           2  BATHGATE                          homes
# 4           2  BATHGATE                          homes
# ...       ...                        ...           ...
# 5263        2  WOODLAWN                     apartments
# 5264        2  WOODLAWN                     apartments
# 5265        2  WOODLAWN                     apartments
# 5266        2  WOODLAWN                     apartments
# 5267        2  WOODLAWN                      buildings
#
#                            building_class_category tax_class_at_present  \
# 0     01  ONE FAMILY HOMES                                            1
# 1     01  ONE FAMILY HOMES                                            1
# 2     01  ONE FAMILY HOMES                                            1
# 3     01  ONE FAMILY HOMES                                            1
# 4     02  TWO FAMILY HOMES                                            1
# ...                                            ...                  ...
# 5263  10  COOPS - ELEVATOR APARTMENTS                                 2
# 5264  10  COOPS - ELEVATOR APARTMENTS                                 2
# 5265  10  COOPS - ELEVATOR APARTMENTS                                 2
# 5266  10  COOPS - ELEVATOR APARTMENTS                                 2
# 5267  22  STORE BUILDINGS                                             4
#
#       block  lot ease_ment building_class_at_present  \
# 0      3028   25                                  A5
# 1      3039   28                                  A1
# 2      3046   39                                  A1
# 3      3046   52                                  A1
# 4      2900   61                                  S2
# ...     ...  ...       ...                       ...
# 5263   3398   87                                  D4
# 5264   3398   87                                  D4
# 5265   3398   97                                  D4
# 5266   3398   97                                  D4
# 5267   3387    3                                  K4
#
#                                         address  ... residential_units  \
# 0     412 EAST 179TH STREET                      ...                 1
# 1     2329 WASHINGTON AVENUE                     ...                 1
# 2     2075 BATHGATE AVENUE                       ...                 1
# 3     2047 BATHGATE AVENUE                       ...                 1
# 4     406 EAST TREMONT AVENUE                    ...                 2
# ...                                         ...  ...               ...
# 5263  4315 WEBSTER AVENUE, 4G                    ...                 0
# 5264  4315 WEBSTER AVENUE, 5D                    ...                 0
# 5265  4295 WEBSTER AVENUE, 2J                    ...                 0
# 5266  4295 WEBSTER AVENUE, 1G                    ...                 0
# 5267  4334 KATONAH AVENUE                        ...                 6
#
#       commercial_units  total_units  land_square_feet  gross_square_feet  \
# 0                    0            1              1842               2048
# 1                    0            1              1103               1290
# 2                    0            1              1986               1344
# 3                    0            1              2329               1431
# 4                    1            3              1855               4452
# ...                ...          ...               ...                ...
# 5263                 0            0                 0                  0
# 5264                 0            0                 0                  0
# 5265                 0            0                 0                  0
# 5266                 0            0                 0                  0
# 5267                 6           12             10000              11160
#
#       year_built  tax_class_at_time_of_sale  building_class_at_time_of_sale  \
# 0           1901                          1                              A5
# 1           1910                          1                              A1
# 2           1899                          1                              A1
# 3           1901                          1                              A1
# 4           1931                          1                              S2
# ...          ...                        ...                             ...
# 5263        1958                          2                              D4
# 5264        1958                          2                              D4
# 5265        1957                          2                              D4
# 5266        1957                          2                              D4
# 5267        1991                          4                              K4
#
#      saleprice  sale_date
# 0       355000 2013-07-08
# 1       474819 2013-05-20
# 2       210000 2013-03-12
# 3       343116 2013-07-01
# 4            0 2012-08-31
# ...        ...        ...
# 5263    150000 2013-02-06
# 5264    108500 2013-04-10
# 5265    126000 2012-09-28
# 5266    125000 2013-05-23
# 5267         0 2012-12-17
#
# [5268 rows x 22 columns]

# %%
grouped_type_build_data = new_data_with_type_building.groupby("type_building",as_index=False).count()
grouped_type_build_data
# Out:
#   type_building  borough  neighborhood  building_class_category  \
# 0    apartments     1295          1295                     1295
# 1     buildings      134           134                      134
# 2        condos      332           332                      332
# 3    facilities       32            32                       32
# 4     factories       30            30                       30
# 5       garages      156           156                      156
# 6         homes     2793          2793                     2793
# 7          land      234           234                      234
# 8         other      211           211                      211
# 9    warehouses       51            51                       51
#
#    tax_class_at_present  block   lot  ease_ment  building_class_at_present  \
# 0                  1295   1295  1295       1295                       1295
# 1                   134    134   134        134                        134
# 2                   332    332   332        332                        332
# 3                    32     32    32         32                         32
# 4                    30     30    30         30                         30
# 5                   156    156   156        156                        156
# 6                  2793   2793  2793       2793                       2793
# 7                   234    234   234        234                        234
# 8                   211    211   211        211                        211
# 9                    51     51    51         51                         51
#
#    address  ...  residential_units  commercial_units  total_units  \
# 0     1295  ...               1295              1295         1295
# 1      134  ...                134               134          134
# 2      332  ...                332               332          332
# 3       32  ...                 32                32           32
# 4       30  ...                 30                30           30
# 5      156  ...                156               156          156
# 6     2793  ...               2793              2793         2793
# 7      234  ...                234               234          234
# 8      211  ...                211               211          211
# 9       51  ...                 51                51           51
#
#    land_square_feet  gross_square_feet  year_built  tax_class_at_time_of_sale  \
# 0              1295               1295        1295                       1295
# 1               134                134         134                        134
# 2               332                332         332                        332
# 3                32                 32          32                         32
# 4                30                 30          30                         30
# 5               156                156         156                        156
# 6              2793               2793        2793                       2793
# 7               234                234         234                        234
# 8               211                211         211                        211
# 9                51                 51          51                         51
#
#    building_class_at_time_of_sale  saleprice  sale_date
# 0                            1295       1295       1295
# 1                             134        134        134
# 2                             332        332        332
# 3                              32         32         32
# 4                              30         30         30
# 5                             156        156        156
# 6                            2793       2793       2793
# 7                             234        234        234
# 8                             211        211        211
# 9                              51         51         51
#
# [10 rows x 22 columns]

# %%
fig, ax = plt.subplots(figsize=(20, 10))
ax = seaborn.barplot( data=grouped_type_build_data, 
                x=grouped_type_build_data.type_building, 
                y=grouped_type_build_data.borough)

# %%
#group_data_by_year = clean_data.groupby("sale_date",as_index=False)
#group_data_by_year
group_data_by_year = clean_data.groupby([clean_data["sale_date"].dt.year, clean_data["sale_date"].dt.month],group_keys=True)["saleprice"].sum()
group_data_by_year.plot(kind = "bar", xlabel="date", ylabel="saleprice")
# Out:
# <AxesSubplot:xlabel='date', ylabel='saleprice'>

# %%
fig, ax = plt.subplots(figsize=(20, 10))
group2 = clean_data.groupby(["type_building"],as_index=False).sum()
ax = seaborn.barplot(data=group2, 
                x=group2.type_building, 
                y=group2.saleprice)
